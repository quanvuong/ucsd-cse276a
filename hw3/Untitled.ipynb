# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
import torch.nn as nn
import pickle

with open('hist_240.pkl', 'rb') as f:
    hists = pickle.load(f)

# hist = [x_est, odo, P_est, innov, S, K]

# %%
hist = hists[79]

x_est = hist[0]
Pmm_est = hist[2][3:, 3:]
Pmm_diag = np.diag(Pmm_est)

print(Pmm_est)
print(Pmm_diag)

plt.clf()

print(f'Number of landmark: {len(x_est[3:]) / 2}')

for idx in range(3, len(x_est), 2):
    plt.plot(x_est[idx], x_est[idx+1], 'bo')

# plt.show()
# Out:
# [[ 1.00000000e-04  9.03433132e-19  1.00000000e-04 -2.23920958e-18
#    1.00000000e-04 -2.21748843e-18  1.00000000e-04  1.02896471e-18
#    1.00000000e-04  9.80905064e-19  1.00000000e-04  1.47690643e-19
#    1.00000000e-04  8.21198215e-19  1.00000000e-04  8.44102842e-19
#    1.00000000e-04  5.79421397e-19  1.00000000e-04  7.93822575e-19
#    1.00000000e-04  4.64354758e-19  1.00000000e-04  6.67380980e-19
#    1.00000000e-04  6.54725488e-19  1.00000000e-04  6.64913969e-19
#    1.00000000e-04  6.68665867e-19]
#  [ 9.03433132e-19  1.00000000e-04  4.16156782e-18  1.00000000e-04
#    9.83576006e-19  1.00000000e-04 -3.99262793e-19  1.00000000e-04
#   -1.29665695e-18  1.00000000e-04  4.51176785e-19  1.00000000e-04
#    4.11555698e-19  1.00000000e-04 -9.81757225e-19  1.00000000e-04
#    1.52268815e-18  1.00000000e-04  1.52899249e-18  1.00000000e-04
#    1.12378787e-18  1.00000000e-04  8.66657374e-19  1.00000000e-04
#    8.78158050e-19  1.00000000e-04  8.79028969e-19  1.00000000e-04
# ...

# %%
for i in range(240):

    x_est = hists[i][0]
    
    plt.clf()
    plt.title(f'Number of landmark: {len(x_est[3:]) / 2}\nIteration: {i}')
    plt.xlabel('x')
    plt.ylabel('y')

    for idx in range(3, len(x_est), 2):
        plt.plot(x_est[idx], x_est[idx+1], 'bo')

    plt.show()
